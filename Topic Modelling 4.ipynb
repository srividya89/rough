# %% [markdown]
#  Create Dictionary and Corpus
# The processed data will now be used to create the dictionary and corpus.

# %% [markdown]
# You're right — gensim.utils.lemmatize() was deprecated and is no longer available in recent versions of Gensim. Instead, you should use spaCy for lemmatization.

# %%
 #Install spaCy and Download English Model
# !pip install spacy
# Out:
# ...
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# ...
#    ---------------------------------------- 0.0/13.9 MB ? eta -:--:--
#    ------------------------------ --------- 10.5/13.9 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------- 13.9/13.9 MB 48.6 MB/s eta 0:00:00
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# ...

# %%
pip install spacy
# Out:
# ...
#
#   Using cached spacy-3.8.7-cp312-cp312-win_amd64.whl.metadata (28 kB)
# ...
#   Using cached murmurhash-1.0.13-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# ...
#   Using cached preshed-3.0.10-cp312-cp312-win_amd64.whl.metadata (2.5 kB)
# ...
#   Using cached thinc-8.3.6-cp312-cp312-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached srsly-2.5.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached blis-1.3.0-cp312-cp312-win_amd64.whl.metadata (7.6 kB)
# ...
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# ...

# %% [markdown]
# Download the English language model

# %%
import spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      -------------------------- ------------- 8.4/12.8 MB 40.0 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 40.2 MB/s eta 0:00:00
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install gensim
# Out:
# ...
#   Using cached gensim-4.3.3-cp312-cp312-win_amd64.whl.metadata (8.2 kB)
# ...
# Using cached gensim-4.3.3-cp312-cp312-win_amd64.whl (24.0 MB)
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    --------------------------- ------------ 10.5/15.5 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 44.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/45.9 MB ? eta -:--:--
#    ------- -------------------------------- 9.2/45.9 MB 47.4 MB/s eta 0:00:01
#    --------- ------------------------------ 11.0/45.9 MB 28.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 12.3/45.9 MB 20.9 MB/s eta 0:00:02
#    ------------ --------------------------- 14.7/45.9 MB 18.1 MB/s eta 0:00:02
#    --------------- ------------------------ 17.6/45.9 MB 17.0 MB/s eta 0:00:02
#    ------------------ --------------------- 21.0/45.9 MB 17.0 MB/s eta 0:00:02
# ...

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp("Artificial Intelligence is transforming the world.")
print([token.lemma_ for token in doc])
# Out:
# ['Artificial', 'Intelligence', 'be', 'transform', 'the', 'world', '.']

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
# !pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# ...
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# ...
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# ...
#
#    ---------------------------------------- 0/3 [regex]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    ------------- -------------------------- 1/3 [joblib]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
# ...

# %%
import gensim
from gensim import corpora
from gensim.models import LdaModel, LdaMulticore
import gensim.downloader as api
from gensim.utils import simple_preprocess
import nltk
from nltk.corpus import stopwords
import spacy
import logging

# Download stopwords and load spaCy model
nltk.download('stopwords')
stop_words = stopwords.words('english') + ['subject', 'com', 'are', 'edu', 'would', 'could']
nlp = spacy.load("en_core_web_sm")

# Logging setup
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')
logging.root.setLevel(level=logging.INFO)

# Load dataset
dataset = api.load("text8")
data = [w for w in dataset]

# Lemmatization function
def lemmatize_with_spacy(word):
    doc = nlp(word)
    return [token.lemma_ for token in doc if token.pos_ in ["NOUN", "ADJ", "ADV"]]

# Processed data
processed_data = []
for doc in data[:100]:
    doc_out = []
    for word in doc:
        if word not in stop_words:
            lems = lemmatize_with_spacy(word)
            if lems:
                doc_out.append(lems[0])
    processed_data.append(doc_out)

print(processed_data[0][:10])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Welcome\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#cant import lemmatize as 
#from gensim.utils import simple_preprocess,lemmatize
#instead use spacy lib

# %% [markdown]
# 8.2.2 Create Dictionary and Corpus
# The processed data will now be used to create the dictionary and corpus.

# %%
dict = corpora.Dictionary(processed_data)
Corpus = [dict.doc2bow(l) for l in processed_data]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dict = corpora.Dictionary(processed_data)
#       2 Corpus = [dict.doc2bow(l) for l in processed_data]
#
# NameError: name 'corpora' is not defined
